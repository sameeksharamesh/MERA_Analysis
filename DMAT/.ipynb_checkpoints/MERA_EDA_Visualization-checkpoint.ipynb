# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("/Users/lakshaykapur/Developer/ADS/MERA_Analysis/DMAT/Mera_CleanData.csv")
print("Dataset Description")
print(df1.info())
# Out:
# Dataset Description
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16441 entries, 0 to 16440
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         16441 non-null  object
#  1   max_temp                     16441 non-null  float64
#  2   min_temp                     16441 non-null  float64
#  3   igmin                        16441 non-null  int64
#  4   min_grass                    16436 non-null  float64
#  5   rain                         16441 non-null  float64
#  6   pressure_cbl                 16441 non-null  float64
#  7   wind_speed                   16441 non-null  float64
#  8   max_10minute_wind            16441 non-null  float64
#  9   dir_10minute_wind            16441 non-null  float64
#  10  max_gust                     16441 non-null  float64
#  11  sun                          16441 non-null  float64
# ...

# %%
df1.head()
# Out:
#          date  max_temp  min_temp  igmin  min_grass  rain  pressure_cbl  \
# 0  1979-10-28     -0.27     -0.36      1      -1.18   0.9         997.9
# 1  1979-10-29     -0.48     -0.48      0      -0.29   0.7         998.8
# 2  1979-10-30      0.48      0.60      0       0.62   4.8         990.8
# 3  1979-10-31     -0.15      0.22      0       0.21   0.5         990.0
# 4  1979-11-01     -0.40     -0.14      0      -0.04   0.0        1001.6
#
#    wind_speed  max_10minute_wind  dir_10minute_wind  ...  temp_range  \
# 0       -0.31              -0.26               0.89  ...         7.5
# 1       -0.45              -0.88               0.42  ...         7.0
# 2        0.92               0.96               0.07  ...         6.9
# 3        0.74               0.96               0.54  ...         5.5
# 4        0.51               0.20               0.42  ...         5.9
#
#    smd_combined  wind_category extreme_rain  heatwave  high_wind  \
# ...

# %%
print("Summary Statistics")
df1.describe()
# Out:
# Summary Statistics
#            max_temp      min_temp         igmin     min_grass          rain  \
# count  16441.000000  16441.000000  16441.000000  16436.000000  16441.000000
# mean       0.000038      0.000030      0.234353      0.000012      1.425522
# std        1.000010      1.000064      0.430020      1.000036      2.016079
# min       -3.680000     -4.130000      0.000000     -3.260000      0.000000
# 25%       -0.720000     -0.750000      0.000000     -0.750000      0.000000
# 50%       -0.030000      0.020000      0.000000      0.040000      0.200000
# 75%        0.790000      0.760000      0.000000      0.750000      2.300000
# max        3.210000      2.770000      4.000000      2.640000      5.750000
#
#        pressure_cbl    wind_speed  max_10minute_wind  dir_10minute_wind  \
# count  16441.000000  16441.000000       16441.000000       16441.000000
# mean    1003.152588      0.000055           0.000048          -0.000096
# ...

# %%
df1['data'] = pd.to_datetime(df1['date'])

# %%
# EDA: Visualizations
eda_figures = {}

# Distribution of target variable: extreme_weather
eda_figures["extreme_weather_dist"] = plt.figure(figsize=(6, 4))
sns.countplot(data=df1, x="extreme_weather", palette="viridis")
plt.title("Distribution of Extreme Events")
plt.xlabel("Extreme Weather (0: No, 1: Yes)")
plt.ylabel("Count")

# Correlation heatmap for numerical features
eda_figures["correlation_heatmap"] = plt.figure(figsize=(12, 10))
numerical_features = df1.select_dtypes(include=["float64", "int64"])
corr_matrix = numerical_features.corr()
sns.heatmap(corr_matrix, annot=False, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")

# Distribution of a numerical feature: (based on extreme_weather)
eda_figures["weather_dist"] = plt.figure(figsize=(6, 4))
sns.histplot(df1["extreme_weather"], kde=True, bins=30, color="blue")
plt.title("Distribution of Extreme Weather")
plt.xlabel("Extreme Weather (0: No, 1: Yes)")
plt.ylabel("Density")

# Boxplot of temperature by extreme_weather
eda_figures["extreme_weather_boxplot"] = plt.figure(figsize=(8, 6))
sns.boxplot(data=df1, x="extreme_weather", y="max_temp", palette="Set2")
plt.title("Temperature vs Extreme Weather")
plt.xlabel("Extreme Weather (0: No, 1: Yes)")
plt.ylabel("Temperature")

# Boxplot of precipitation by extreme_weather
eda_figures["extreme_weather_boxplot"] = plt.figure(figsize=(8, 6))
sns.boxplot(data=df1, x="extreme_weather", y="rain", palette="Set2")
plt.title("Precipitation vs Extreme Weather")
plt.xlabel("Extreme Weather (0: No, 1: Yes)")
plt.ylabel("Precipitation")


# Boxplot of wind speed by extreme_weather
eda_figures["extreme_weather_boxplot"] = plt.figure(figsize=(8, 6))
sns.boxplot(data=df1, x="extreme_weather", y="wind_speed", palette="Set2")
plt.title("Wind Speed vs Extreme Weather")
plt.xlabel("Extreme Weather (0: No, 1: Yes)")
plt.ylabel("Wind Speed")

# Pairplot of selected features (use extreme_weather as hue)
selected_features = ["rain", "pressure_cbl", "wind_speed", "temp_range", "extreme_weather"]
eda_figures["pairplot"] = sns.pairplot(df1[selected_features], hue="extreme_weather", palette="husl")

eda_figures
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
